# %%
import sys
sys.path.append('..')
from feature_viz.show_sae_feature import show_sae_feature
# Out:
# /Users/tz20913/miniconda3/lib/python3.11/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /Users/tz20913/miniconda3/lib/python3.11/site-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /Users/tz20913/miniconda3/lib/python3.11/site-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
show_sae_feature(
    sae_path='../artifacts/sparse_autoencoder_gelu-1l_blocks.0.hook_resid_mid_16384:v4/final_sparse_autoencoder_gelu-1l_blocks.0.hook_resid_mid_16384.pt',
    hook_point='resid_mid',
    hook_layer=0,
    feature_idx=623,
    max_batch_size=256,
    # n_batches_to_sample_from=64,
    # n_prompts_to_select=16,
)
# Out:
# Loaded pretrained model gelu-1l into HookedTransformer
# Moving model to device:  mps
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 show_sae_feature(
#       2     sae_path='../artifacts/sparse_autoencoder_gelu-1l_blocks.0.hook_resid_mid_16384:v4/final_sparse_autoencoder_gelu-1l_blocks.0.hook_resid_mid_16384.pt',
#       3     hook_point='resid_mid',
#       4     hook_layer=0,
#       5     feature_idx=623,
#       6     max_batch_size=256,
#       7     # n_batches_to_sample_from=64,
#       8     # n_prompts_to_select=16,
#       9 )
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Desktop/Research/MATS_Neel/SAE_layer_computation/feature_viz/../feature_viz/show_sae_feature.py:46, in show_sae_feature(sae_path, hook_point, hook_layer, feature_idx, n_batches_to_sample_from, n_prompts_to_select, max_batch_size)
# ...
